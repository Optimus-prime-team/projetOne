# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Ascii" data-toc-modified-id="Ascii-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Ascii</a></span></li><li><span><a href="#Import" data-toc-modified-id="Import-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import</a></span><ul class="toc-item"><li><span><a href="#Import-librairies" data-toc-modified-id="Import-librairies-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Import librairies</a></span></li><li><span><a href="#Import-base-de-donnée" data-toc-modified-id="Import-base-de-donnée-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Import base de donnée</a></span><ul class="toc-item"><li><span><a href="#function-pour-connection-MongoDb" data-toc-modified-id="function-pour-connection-MongoDb-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>function pour connection MongoDb</a></span></li></ul></li><li><span><a href="#Function-pour-load-la-base-de-donnée-en-Data-Frame" data-toc-modified-id="Function-pour-load-la-base-de-donnée-en-Data-Frame-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Function pour load la base de donnée en Data Frame</a></span><ul class="toc-item"><li><span><a href="#Load-csv" data-toc-modified-id="Load-csv-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Load csv</a></span></li><li><span><a href="#Description-Features" data-toc-modified-id="Description-Features-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Description Features</a></span></li></ul></li></ul></li><li><span><a href="#Analyse-rapide-du-Data_Frame" data-toc-modified-id="Analyse-rapide-du-Data_Frame-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Analyse rapide du Data_Frame</a></span><ul class="toc-item"><li><span><a href="#Taille-data_frame" data-toc-modified-id="Taille-data_frame-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Taille data_frame</a></span><ul class="toc-item"><li><span><a href="#remplacement-valeur-manquante-par-Nan" data-toc-modified-id="remplacement-valeur-manquante-par-Nan-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>remplacement valeur manquante par Nan</a></span></li></ul></li><li><span><a href="#info-sur-la-data_frame" data-toc-modified-id="info-sur-la-data_frame-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>info sur la data_frame</a></span></li><li><span><a href="#Transformation-colonne-salary-en-int()" data-toc-modified-id="Transformation-colonne-salary-en-int()-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Transformation colonne salary en int()</a></span></li><li><span><a href="#Nombre-de-valeur-unique-par-columns" data-toc-modified-id="Nombre-de-valeur-unique-par-columns-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Nombre de valeur unique par columns</a></span></li><li><span><a href="#Compte-des-valeurs-manquantes" data-toc-modified-id="Compte-des-valeurs-manquantes-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Compte des valeurs manquantes</a></span></li><li><span><a href="#Histo-pour-les-columns" data-toc-modified-id="Histo-pour-les-columns-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Histo pour les columns</a></span></li></ul></li><li><span><a href="#Clean-data_frame" data-toc-modified-id="Clean-data_frame-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Clean data_frame</a></span><ul class="toc-item"><li><span><a href="#replace-&quot;&quot;-par-des-Nan" data-toc-modified-id="replace-&quot;&quot;-par-des-Nan-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>replace "" par des Nan</a></span></li><li><span><a href="#Gestion-colonne-title" data-toc-modified-id="Gestion-colonne-title-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Gestion colonne title</a></span><ul class="toc-item"><li><span><a href="#Data-Scientist" data-toc-modified-id="Data-Scientist-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Data Scientist</a></span></li><li><span><a href="#Data-Analyst" data-toc-modified-id="Data-Analyst-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Data Analyst</a></span></li><li><span><a href="#Developpeur" data-toc-modified-id="Developpeur-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Developpeur</a></span></li><li><span><a href="#Freelance" data-toc-modified-id="Freelance-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Freelance</a></span></li><li><span><a href="#Remplacement-colonne-Title" data-toc-modified-id="Remplacement-colonne-Title-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Remplacement colonne Title</a></span></li></ul></li><li><span><a href="#Clean-text" data-toc-modified-id="Clean-text-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Clean text</a></span><ul class="toc-item"><li><span><a href="#Expemple-de-la-colonne-description" data-toc-modified-id="Expemple-de-la-colonne-description-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Expemple de la colonne description</a></span></li><li><span><a href="#Préparation" data-toc-modified-id="Préparation-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Préparation</a></span></li><li><span><a href="#Print-des-5-1er-éxemple" data-toc-modified-id="Print-des-5-1er-éxemple-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Print des 5 1er éxemple</a></span></li></ul></li></ul></li><li><span><a href="#World-Cloud" data-toc-modified-id="World-Cloud-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>World Cloud</a></span><ul class="toc-item"><li><span><a href="#import-pour-World-Cloud" data-toc-modified-id="import-pour-World-Cloud-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>import pour World Cloud</a></span></li><li><span><a href="#World-Cloud-description" data-toc-modified-id="World-Cloud-description-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>World Cloud description</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Ascii

# %%
##########################################
#          _ _,---._                     #
#       ,-','       `-.___               #
#      /-;'               `._            #
#     /\/          ._   _,'o \           #
#    ( /\       _,--'\,','"`. )          #
#     |\      ,'o     \'    //\          #
#     |      \        /   ,--'""`-.      #
#     :       \_    _/ ,-'         `-._  #
#      \        `--'  /                ) #
#       `.  \`._    ,'     ________,','  #
#         .--`     ,'  ,--` __\___,;'    #
#          \`.,-- ,' ,`_)--'  /`.,'      #
#           \( ;  | | )      (`-/        #
#             `--'| |)       |-/         #
#               | | |        | |         #
#               | | |,.,-.   | |_        #
#               | `./ /   )---`  )       #
#              _|  /    ,',   ,-'        #
#             ,'|_(    /-<._,' |--,      #
#             |    `--'---.     \/ \     #
#             |          / \    /\  \    #
#           ,-^---._     |  \  /  \  \   #
#        ,-'        \----'   \/    \--`. #
#       /            \              \   \#
##########################################
#                  Gruy                  #
##########################################

# %% [markdown]
# ## Import

# %% [markdown]
# ### Import librairies

# %%
import pymongo

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.style.use('ggplot')

# %% [markdown]
# ### Import base de donnée

# %% [markdown]
# #### function pour connection MongoDb

# %%
def get_connection() :
    client = pymongo.MongoClient("mongodb+srv://nico:root@cluster0-fgi6m.azure.mongodb.net/test?retryWrites=true&w=majority")
    #db = client.test
    #myclient = pymongo.MongoClient("mongodb://localhost:27017/")

    dblist = client.list_database_names()
    if "mydatabase" not in dblist:
        print('db created')
      
    mydb = client["mydatabase"]
    
    collist = mydb.list_collection_names()
    if "offres_indeed" not in collist:
        print('collection created')
    mycol = mydb["offres_indeed"]
    return mycol

# %% [markdown]
# ### Function pour load la base de donnée en Data Frame

# %%
def load_offers ():
    mycol = get_connection()
    mylist = mycol.find()
    df = pd.DataFrame(list(mylist))
    
    if len(df) != 0 :
        del df['_id']
    print('il y a actuellement : '+str(len(df))+' elements dans la collection')
    return df

# %% [markdown]
# #### Load csv

# %%
df = load_offers()
df.head()
# Out:
# il y a actuellement : 8563 elements dans la collection
#              city                     contrat salary  \
# 0  Montrouge (92)  Apprentissage, Contrat pro
# 1     Clichy (92)                         CDI
# 2      Paris (75)                       Stage
# 3      Paris (75)          Temps plein, Stage  18000
# 4  Paris 17e (75)          Temps plein, Stage    800
#
#                                          title   compagnyName  \
# 0     Analyste de contrats de financements H/F  CA CIB FRANCE
# 1                             Data Analyst H/F        Sarenza
# 2                   Stage - Data Analyst (F/H)    Groupe BPCE
# 3             Data Analyst·(e) - Stagiaire H/F           VONA
# 4  Data Analyst GreenTech [STAGE – 4 à 6 MOIS]  Inex Circular
#
#                                          description  postdate  overOneMounth  \
# 0  Crédit Agricole CIB est la banque de financeme...  04/20/20            1.0
# 1  Monoprix repense son offre e-commerce alimenta...  05/07/20            0.0
# 2  Description de l'entreprise\nVous souhaitez tr...  05/14/20            0.0
# 3  Depuis 2010, VONA Consulting, cabinet de conse...  05/05/20            0.0
# 4  Ton rôle\nAu cœur du développement, tu travail...  05/14/20            0.0
#
#      job_querry city_querry
# 0  data analyst       Paris
# 1  data analyst       Paris
# 2  data analyst       Paris
# 3  data analyst       Paris
# 4  data analyst       Paris

# %% [markdown]
# #### Description Features

# %% [markdown]
# - city
# - contrat salary
# - titlle
# - comapagnyName
# - description
# - postdate
# - overOneMounth
# - job_query
# - city_querry

# %% [markdown]
# ## Analyse rapide du Data_Frame

# %% [markdown]
# ### Taille data_frame

# %%
df.shape
# Out:
# (8563, 10)

# %% [markdown]
# #### remplacement valeur manquante par Nan

# %%
df = df.replace(r'^\s*$', np.nan, regex=True)

# %% [markdown]
# ### info sur la data_frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8563 entries, 0 to 8562
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   city           7383 non-null   object
#  1   contrat        4967 non-null   object
#  2   salary         1316 non-null   float64
#  3   title          7402 non-null   object
#  4   compagnyName   7401 non-null   object
#  5   description    7402 non-null   object
#  6   postdate       8563 non-null   object
#  7   overOneMounth  8563 non-null   float64
#  8   job_querry     7597 non-null   object
#  9   city_querry    7597 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 669.1+ KB

# %% [markdown]
# ### Transformation colonne salary en int()
# - pd.to_numerci pour changer en float
# - errors pour transfomer en Nan ce qu'il n'arrive pa à transformer en float

# %%
df['salary'] = pd.to_numeric(df['salary'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-11178d9e9d1b> in <module>
#       1 df['salary'] = pd.to_numeric(df['salary'], errors='coerce')
# ----> 2 df['title'] = pd.to_string(df['title'])
#
# E:\systeme\anaconda\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'to_string'

# %%
df.head(100)
# Out:
#                    city                                  contrat   salary  \
# 0        Montrouge (92)               Apprentissage, Contrat pro      NaN
# 1           Clichy (92)                                      CDI      NaN
# 2            Paris (75)                                    Stage      NaN
# 3            Paris (75)                       Temps plein, Stage  18000.0
# 4        Paris 17e (75)                       Temps plein, Stage    800.0
# ..                  ...                                      ...      ...
# 95        Malakoff (92)  Temps plein, Apprentissage, Contrat pro      NaN
# 96  Chilly-Mazarin (91)  Temps plein, Apprentissage, Contrat pro      NaN
# 97       Montrouge (92)                                      CDI      NaN
# 98          Meudon (92)                         Temps plein, CDI      NaN
# 99     Bois-d'Arcy (78)                         Temps plein, CDI  28000.0
#
#                                                 title          compagnyName  \
# 0            Analyste de contrats de financements H/F         CA CIB FRANCE
# 1                                    Data Analyst H/F               Sarenza
# 2                          Stage - Data Analyst (F/H)           Groupe BPCE
# 3                    Data Analyst·(e) - Stagiaire H/F                  VONA
# 4         Data Analyst GreenTech [STAGE – 4 à 6 MOIS]         Inex Circular
# ..                                                ...                   ...
# 95        Alternance - Assistant Data Analyst/PMO H/F      Malakoff Humanis
# 96                  UN ALTERNANT – DATA ANALYST (H/F)                Sanofi
# 97                                   Data Analyst H/F  Crédit Agricole S.A.
# 98                                 Data Analyst (F/H)      Bouygues Telecom
# 99  Junior Data Analyst - Environnement Commercial...           Atmospheres
#
#                                           description           postdate  \
# 0   Crédit Agricole CIB est la banque de financeme...           04/20/20
# 1   Monoprix repense son offre e-commerce alimenta...           05/07/20
# 2   Description de l'entreprise\nVous souhaitez tr...           05/14/20
# 3   Depuis 2010, VONA Consulting, cabinet de conse...           05/05/20
# 4   Ton rôle\nAu cœur du développement, tu travail...           05/14/20
# ..                                                ...                ...
# 95  Malakoff Humanis est un groupe de protection s...           05/19/20
# 96  SANOFI a pour ambition d'être un Leader Mondia...  05/20/20-10:38:38
# 97  Société cotée, Crédit Agricole SA est l'organe...           05/15/20
# 98  En qualité de Data Analyst, vous serez intégré...           04/30/20
# 99  Descriptif société\nAtmosphères est une agence...           05/15/20
#
#     overOneMounth    job_querry city_querry
# 0             1.0  data analyst       Paris
# 1             0.0  data analyst       Paris
# 2             0.0  data analyst       Paris
# 3             0.0  data analyst       Paris
# 4             0.0  data analyst       Paris
# ..            ...           ...         ...
# 95            0.0           NaN         NaN
# 96            0.0           NaN         NaN
# 97            0.0           NaN         NaN
# 98            0.0           NaN         NaN
# 99            0.0           NaN         NaN
#
# [100 rows x 10 columns]

# %%
df.describe()
# Out:
#               salary  overOneMounth
# count    1316.000000    8563.000000
# mean    41202.539514       0.547705
# std     16295.168944       0.497748
# min         6.000000       0.000000
# 25%     35000.000000       0.000000
# 50%     41605.500000       1.000000
# 75%     50000.000000       1.000000
# max    130000.000000       1.000000

# %% [markdown]
# ### Nombre de valeur unique par columns

# %%
df.nunique()
# Out:
# city              241
# contrat            48
# salary            202
# title            5297
# compagnyName     2228
# description      6037
# postdate         1510
# overOneMounth       2
# job_querry          4
# city_querry         5
# dtype: int64

# %% [markdown]
# ### Compte des valeurs manquantes

# %%
df.isnull().sum()
# Out:
# city             1180
# contrat          3596
# salary           7247
# title            1161
# compagnyName     1162
# description      1161
# postdate            0
# overOneMounth       0
# job_querry        966
# city_querry       966
# dtype: int64

# %% [markdown]
# ### Histo pour les columns

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000188F986E788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000188F98876C8>]],
#       dtype=object)

# %% [markdown]
# ## Clean data_frame

# %% [markdown]
# ### replace "" par des Nan

# %%
df.drop(index = df[df['description'].isnull()].index, inplace = True)

# %%
df.isnull().sum()
# Out:
# city               19
# contrat          2435
# salary           6086
# title               0
# compagnyName        1
# description         0
# postdate            0
# overOneMounth       0
# job_querry        966
# city_querry       966
# dtype: int64

# %% [markdown]
# ### Gestion colonne title

# %%
data = df.copy()
# on passe tout en capitale
data['title']=[x.upper() for x in data['title']]
print(data['title'])
# Out:
# 0                ANALYSTE DE CONTRATS DE FINANCEMENTS H/F
# 1                                        DATA ANALYST H/F
# 2                              STAGE - DATA ANALYST (F/H)
# 3                        DATA ANALYST·(E) - STAGIAIRE H/F
# 4             DATA ANALYST GREENTECH [STAGE – 4 À 6 MOIS]
#                               ...
# 8558                    DEVELOPPEUR J2EE FULL STACK - F/H
# 8559                                   DÉVELOPPEUR C# H/F
# 8560    (ALTERNANCE) DÉVELOPPEUR FRONTEND - CHEZ L’UN ...
# 8561    (ALTERNANCE) DÉVELOPPEUR JAVA - CHEZ L’UN DE N...
# 8562          SOFTWARE DEVELOPER FULL STACK (JEE/ANGULAR)
# Name: title, Length: 7402, dtype: object

# %% [markdown]
# #### Data Scientist

# %%
data.loc[data.title.str.contains("SCIENTIST"), 'title'] = 'Data Scientist'

# %% [markdown]
# #### Data Analyst

# %%
data.loc[data.title.str.contains('ANALYST'), 'title'] = 'Data Analyst'
data.loc[data.title.str.contains('STATISTICIAN'), 'title'] = 'Data Analyst'

# %% [markdown]
# #### Developpeur

# %%
data.loc[data.title.str.contains('DEVELOPPEUR'), 'title'] = 'Développeur'

# %% [markdown]
# #### Freelance

# %%
data.loc[data.title.str.contains('FREELANCE'), 'title'] = 'Freelance'

# %% [markdown]
# #### Remplacement colonne Title

# %%
data.title = data[(data.title == 'Data Scientist') | (data.title == 'Data Analyst') | (data.title == 'Développeur') | (data.title == 'Freelance')]
# data.title=['Others' if x is np.nan else x for x in data.title]
data.head()
# Out:
#              city                     contrat   salary   title   compagnyName  \
# 0  Montrouge (92)  Apprentissage, Contrat pro      NaN  Others  CA CIB FRANCE
# 1     Clichy (92)                         CDI      NaN  Others        Sarenza
# 2      Paris (75)                       Stage      NaN  Others    Groupe BPCE
# 3      Paris (75)          Temps plein, Stage  18000.0  Others           VONA
# 4  Paris 17e (75)          Temps plein, Stage    800.0  Others  Inex Circular
#
#                                          description  postdate  overOneMounth  \
# 0  Crédit Agricole CIB est la banque de financeme...  04/20/20            1.0
# 1  Monoprix repense son offre e-commerce alimenta...  05/07/20            0.0
# 2  Description de l'entreprise\nVous souhaitez tr...  05/14/20            0.0
# 3  Depuis 2010, VONA Consulting, cabinet de conse...  05/05/20            0.0
# 4  Ton rôle\nAu cœur du développement, tu travail...  05/14/20            0.0
#
#      job_querry city_querry
# 0  data analyst       Paris
# 1  data analyst       Paris
# 2  data analyst       Paris
# 3  data analyst       Paris
# 4  data analyst       Paris

# %%
data.nunique()
# Out:
# city              241
# contrat            48
# salary            202
# title               1
# compagnyName     2228
# description      6037
# postdate          362
# overOneMounth       2
# job_querry          4
# city_querry         5
# dtype: int64

# %% [markdown]
# ### Clean text

# %% [markdown]
# #### Expemple de la colonne description

# %%
df.description.values[0][0:int(len(df.description.values[0])/2)]
# Out:
# "Crédit Agricole CIB est la banque de financement de d'investissement du groupe Crédit Agricole, 12e groupe bancaire mondial par les fonds propres Tier1 (The Banker, juillet 2018). Près de 8300 collaborateurs répartis en Europe, Amériques, Asie-Pacifique, Moyen-Orient et Afrique du Nord, accompagnent les clients de la Banque dans la couverture de leurs besoins financiers à travers le monde. Crédit Agricole CIB propose à ses clients grandes entreprises et institutionnels une gamme de produits et services dans les métiers de la banque de marchés, de la banque d'investissement, des financements structurés, de la banque commerciale et du commerce international. Pionnier dans le domaine de la finance Climat, la Banque occupe aujourd'hui une position de leader sur ce segment avec une offre complète pour l'ensemble de ses clients. Pour plus d'information : www.ca-cib.fr Twitter: https://twitter.com/ca_cib LinkedIn: https://www.linkedin.com/company/credit-agricole-cib/\n\nRisk & Permanent Control assure le contrôle de l’ensemble des risques du groupe Crédit Agricole CIB. Elle pilote aussi le réseau des Correspondants du Contrôle Permanent.\nLe département RPC-CAM est en charge du monitoring et du contrôle des risques de contrepartie de la banque, du maintien et du suivi de la qualité des données utilisées, et de reportings (internes et/ou réglementaires) de ces données.\n\nPlus précisément, la mission se déroulera au sein de l'équipe Gestion des Contrats et contrôle des Certifications (GCC). Cette équipe veille à la correcte retranscription de la politique netting et collatéral dans les systèmes dédiés (Master Data Base et Netting Tool). En outre, ce secteur assure l’animation et le secrétariat permanent du Comité Politique Netting et Collateral, du Comité Anomalies Opérations non couvertes par des contrats-cadres et du Comité Chambre de Compensation (CCP) et fait le contrôle de la certification sur base d'échantillonnage.\n\nLa mission porte principalement sur :\n1) L’analyse et l’audit de la documentation de financement par rapport aux décisions d’"

# %% [markdown]
# #### Préparation

# %%
text = df.description.values

# %% [markdown]
# #### Print des 5 1er éxemple

# %%
limit = 0
for t in text:
    for sentance in t.split('\n'):
        if 'experience' in sentance:
            year = re.findall("\d{1,2}\+? year", sentance)
            if len(year)==1:
                print(year[0])
                print(sentance)
                print("*"*20)
                limit +=1
    if limit >= 5:
        break
# Out:
# 5 year
# Minimum of 3-5 years of relevant experience in data science role
# ********************
# 1+ year
# 1+ year(s) of work experience in a university, industry, or government lab(s), in a role with primary emphasis on AI research.
# ********************
# 1+ year
# Have 1+ years of experience with a scripting or OO language, ideally Python.
# ********************
# 4 year
# +4 years experience in industry in a similar role
# ********************
# 4+ year
# 4+ years of experience in Python coding applied to the implementation of out-of-the-box models
# ********************

# %%
# Compile the year value found into a list
experience_req = []
for t in text:
    for sentance in t.split('\n'):
        if 'experience' in sentance:
            year = re.findall("\d{1,2}\+? year", sentance)
            if len(year)==1:
                num = year[0].split(' ')
                experience_req.append(num[0])

# %% [markdown]
# ## World Cloud

# %% [markdown]
# ### import pour World Cloud

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from wordcloud import WordCloud, STOPWORDS
import nltk.tokenize as word_tokenize
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
import re
from nltk.stem.porter import *
from nltk.tokenize import sent_tokenize
from sklearn.feature_extraction import stop_words
import random

# %% [markdown]
# ### World Cloud description

# %%
def grey_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(60, 100)

# %%
stopwords = set(STOPWORDS)
newStopWords = ['job_querry', 'description', 'contrat','city']
stopwords.update(newStopWords)

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=1500,
                          max_font_size=200, 
                          width=1000, height=600,
                          random_state=42,
                         ).generate(" ".join(df['title'].astype(str)))

fig = plt.figure(figsize = (12,12))
plt.imshow(wordcloud.recolor(color_func=grey_color_func, random_state=3),
           interpolation="bilinear")
plt.title("WORD CLOUD title", fontsize=25)
plt.axis('off')
plt.show()

# %%
from PIL import Image

# %%
mask = np.array(Image.open("sherlock.jpeg"))
mask2 = np.array(Image.open("sherlock6.jpg"))
mask3 = np.array(Image.open("sherlock8.jpg"))

# %%
stopwords = set(STOPWORDS)
newStopWords = ['job_querry', 'description', 'contrat','city']
stopwords.update(newStopWords)

wordcloud = WordCloud(
                          background_color='black',                        
                          stopwords=stopwords,
                          mask=mask,
                          margin=10,
                          max_words=1500,
                          max_font_size=200, 
                          width=875, height=620,
                          
                          random_state=42,  
                         ).generate(" ".join(df['title'].astype(str)))

fig = plt.figure(figsize = (12,12))
plt.imshow(wordcloud.recolor(color_func=grey_color_func, random_state=3),
           interpolation="bilinear")
plt.title("WORD CLOUD title", fontsize=25)
plt.axis('off')
plt.show()

# %%
stopwords = set(STOPWORDS)
newStopWords = ['job_querry', 'description', 'contrat','city']
stopwords.update(newStopWords)

wordcloud = WordCloud(
                        background_color="black", 
                        stopwords=stopwords, 
                        mask=mask2,
                        width=875, height=620,
                        random_state=42,
                    ).generate(" ".join(df['title'].astype(str)))

# face color pour enlever la bordure
fig = plt.figure(figsize = (12,12), facecolor='k')
# appel fonction grey_color_func
plt.imshow(wordcloud.recolor(color_func=grey_color_func, random_state=3),
           interpolation="bilinear")
# plt.tight_layout pour la bordure
plt.tight_layout(pad=0)

plt.axis('off')
plt.show()

# %%
stopwords = set(STOPWORDS)
newStopWords = ['job_querry', 'description', 'contrat','city']
stopwords.update(newStopWords)

wordcloud = WordCloud(
                        background_color="black", 
                        stopwords=stopwords, 
                        mask=mask3,
                        width=875, height=620,
                        random_state=42,
                    ).generate(" ".join(df['title'].astype(str)))

# face color pour enlever la bordure
fig = plt.figure(figsize = (12,12), facecolor='k')
# appel fonction grey_color_func
plt.imshow(wordcloud.recolor(color_func=grey_color_func, random_state=3),
           interpolation="bilinear")
# plt.tight_layout pour la bordure
plt.tight_layout(pad=0)

plt.axis('off')
plt.show()
